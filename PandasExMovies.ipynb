# %% [markdown]
# # PANDAS - EXERCISES MOVIES

# %% [markdown]
# ## https://www.w3resource.com/python-exercises/pandas/movies/index.php

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Write a Python Pandas program to get the columns of the DataFrame (movies_metadata.csv file).

# %%
dfm= pd.read_csv("movies_metadata.csv",error_bad_lines=False, encoding='Latin1')
# Out:
# b'Skipping line 31: expected 24 fields, saw 25\n'

# %%
dfm.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# 2. Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file) including data types and memory usage.

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 24 columns):
# adult                    49 non-null bool
# belongs_to_collection    10 non-null object
# budget                   49 non-null int64
# genres                   49 non-null object
# homepage                 5 non-null object
# id                       49 non-null int64
# imdb_id                  49 non-null object
# original_language        49 non-null object
# original_title           49 non-null object
# overview                 48 non-null object
# popularity               49 non-null float64
# poster_path              49 non-null object
# production_companies     49 non-null object
# production_countries     49 non-null object
# release_date             49 non-null object
# revenue                  49 non-null int64
# runtime                  49 non-null float64
# spoken_languages         49 non-null object
# status                   49 non-null object
# tagline                  40 non-null object
# title                    49 non-null object
# video                    49 non-null bool
# vote_average             49 non-null float64
# vote_count               49 non-null int64
# dtypes: bool(2), float64(3), int64(4), object(15)
# memory usage: 8.6+ KB

# %% [markdown]
# 3. Write a Pandas program to get the details of the third movie of the DataFrame (movies_metadata.csv file).

# %%
dfm.iloc[2]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies     [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    1995-12-22
# revenue                                                                  0
# runtime                                                                101
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                            Released
# tagline                  Still Yelling. Still Fighting. Still Ready for...
# title                                                     Grumpier Old Men
# video                                                                False
# vote_average                                                           6.5
# vote_count                                                              92
# Name: 2, dtype: object

# %% [markdown]
# 4. Write a Pandas program to count the number of rows and columns of the DataFrame (movies_metadata.csv file).

# %%
dfm.shape
# Out:
# (49, 24)

# %% [markdown]
# 5. Write a Pandas program to get the details of the columns title and genres of the DataFrame.

# %%
dfm[['title','genres']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# 5                             Heat
# 6                          Sabrina
# 7                     Tom and Huck
# 8                     Sudden Death
# 9                        GoldenEye
# 10          The American President
# 11     Dracula: Dead and Loving It
# 12                           Balto
# 13                           Nixon
# 14                Cutthroat Island
# 15                          Casino
# 16           Sense and Sensibility
# 17                      Four Rooms
# 18  Ace Ventura: When Nature Calls
# 19                     Money Train
# 20                      Get Shorty
# 21                         Copycat
# 22                       Assassins
# 23                          Powder
# 24               Leaving Las Vegas
# 25                         Othello
# 26                    Now and Then
# 27                      Persuasion
# 28       The City of Lost Children
# 29                 Dangerous Minds
# 30                  Twelve Monkeys
# 31                Wings of Courage
# 32                            Babe
# 33                      Carrington
# 34                Dead Man Walking
# 35          Across the Sea of Time
# 36                    It Takes Two
# 37                        Clueless
# 38        Cry, the Beloved Country
# 39                     Richard III
# 40                 Dead Presidents
# 41                     Restoration
# 42                   Mortal Kombat
# 43                      To Die For
# 44   How To Make An American Quilt
# 45                           Se7en
# 46                      Pocahontas
# 47           When Night Is Falling
# 48              The Usual Suspects
#
#                                                genres
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 20  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 21  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 22  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 24  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 25                      [{'id': 18, 'name': 'Drama'}]
# 26  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# 29  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 30  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 31  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 32  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 33  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 34                      [{'id': 18, 'name': 'Drama'}]
# 35  [{'id': 12, 'name': 'Adventure'}, {'id': 36, '...
# 36  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 37  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 38                      [{'id': 18, 'name': 'Drama'}]
# 39  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 41  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 42  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# 43  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 44  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 45  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 46  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 47  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...

# %% [markdown]
# 6. Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'

# %%
dfm[dfm['title']== 'Grumpier Old Men'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 2 to 2
# Data columns (total 24 columns):
# adult                    1 non-null bool
# belongs_to_collection    1 non-null object
# budget                   1 non-null int64
# genres                   1 non-null object
# homepage                 0 non-null object
# id                       1 non-null int64
# imdb_id                  1 non-null object
# original_language        1 non-null object
# original_title           1 non-null object
# overview                 1 non-null object
# popularity               1 non-null float64
# poster_path              1 non-null object
# production_companies     1 non-null object
# production_countries     1 non-null object
# release_date             1 non-null object
# revenue                  1 non-null int64
# runtime                  1 non-null float64
# spoken_languages         1 non-null object
# status                   1 non-null object
# tagline                  1 non-null object
# title                    1 non-null object
# video                    1 non-null bool
# vote_average             1 non-null float64
# vote_count               1 non-null int64
# dtypes: bool(2), float64(3), int64(4), object(15)
# memory usage: 186.0+ bytes

# %% [markdown]
# 8. Write a Pandas program to create a smaller DataFrame with a subset of all features.

# %%
dfm.sample(5)
# Out:
#     adult belongs_to_collection    budget  \
# 8   False                   NaN  35000000
# 19  False                   NaN  60000000
# 35  False                   NaN         0
# 21  False                   NaN         0
# 27  False                   NaN         0
#
#                                                genres homepage      id  \
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN    9091
# 19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN   11517
# 35  [{'id': 12, 'name': 'Adventure'}, {'id': 36, '...      NaN  139405
# 21  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN    1710
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   17015
#
#       imdb_id original_language          original_title  \
# 8   tt0114576                en            Sudden Death
# 19  tt0113845                en             Money Train
# 35  tt0112286                en  Across the Sea of Time
# 21  tt0112722                en                 Copycat
# 27  tt0114117                en              Persuasion
#
#                                              overview  ...  release_date  \
# 8   International action superstar Jean Claude Van...  ...    1995-12-22
# 19  A vengeful New York transit cop decides to ste...  ...    1995-11-21
# 35  A young Russian boy, Thomas Minton, travels to...  ...    1995-10-20
# 21  An agoraphobic psychologist and a female detec...  ...    1995-10-27
# 27  This film adaptation of Jane Austen's last nov...  ...    1995-09-27
#
#      revenue runtime                                   spoken_languages  \
# 8   64350171   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19  35431113   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 35         0    51.0  [{'iso_639_1': 'ru', 'name': 'P??????'}, {'iso...
# 21         0   124.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 27         0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 8   Released                         Terror goes into overtime.
# 19  Released                        Get on, or GET OUT THE WAY!
# 35  Released                                                NaN
# 21  Released  One man is copying the most notorious killers ...
# 27  Released                                                NaN
#
#                      title  video vote_average vote_count
# 8             Sudden Death  False          5.5        174
# 19             Money Train  False          5.4        224
# 35  Across the Sea of Time  False          3.5          2
# 21                 Copycat  False          6.5        199
# 27              Persuasion  False          7.4         36
#
# [5 rows x 24 columns]

# %%
small_dfm= dfm[['title', 'release_date', 'budget', 'revenue', 'runtime', 'vote_average', 'vote_count']].sample(30)
small_dfm
# Out:
#                              title release_date    budget    revenue  runtime  \
# 10          The American President   1995-11-17  62000000  107879496    106.0
# 14                Cutthroat Island   1995-12-22  98000000   10017322    119.0
# 46                      Pocahontas   1995-06-14  55000000  346079773     81.0
# 36                    It Takes Two   1995-11-17         0          0    101.0
# 30                  Twelve Monkeys   1995-12-29  29500000  168840000    129.0
# 12                           Balto   1995-12-22         0   11348324     78.0
# 34                Dead Man Walking   1995-12-29  11000000   39363635    122.0
# 1                          Jumanji   1995-12-15  65000000  262797249    104.0
# 3                Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 21                         Copycat   1995-10-27         0          0    124.0
# 24               Leaving Las Vegas   1995-10-27   3600000   49800000    112.0
# 18  Ace Ventura: When Nature Calls   1995-11-10  30000000  212385533     90.0
# 15                          Casino   1995-11-22  52000000  116112375    178.0
# 4      Father of the Bride Part II   1995-02-10         0   76578911    106.0
# 11     Dracula: Dead and Loving It   1995-12-22         0          0     88.0
# 37                        Clueless   1995-07-19  12000000          0     97.0
# 39                     Richard III   1995-12-29         0          0    104.0
# 48              The Usual Suspects   1995-07-19   6000000   23341568    106.0
# 8                     Sudden Death   1995-12-22  35000000   64350171    106.0
# 45                           Se7en   1995-09-22  33000000  327311859    127.0
# 42                   Mortal Kombat   1995-08-18  18000000  122195920    101.0
# 31                Wings of Courage   1996-09-18         0          0     50.0
# 9                        GoldenEye   1995-11-16  58000000  352194034    130.0
# 38        Cry, the Beloved Country   1995-12-15         0     676525    106.0
# 27                      Persuasion   1995-09-27         0          0    104.0
# 28       The City of Lost Children   1995-05-16  18000000    1738611    108.0
# 16           Sense and Sensibility   1995-12-13  16500000  135000000    136.0
# 7                     Tom and Huck   1995-12-22         0          0     97.0
# 0                        Toy Story   1995-10-30  30000000  373554033     81.0
# 33                      Carrington   1995-11-08         0          0    121.0
#
#     vote_average  vote_count
# 10           6.5         199
# 14           5.7         137
# 46           6.7        1509
# 36           6.1         149
# 30           7.4        2470
# 12           7.1         423
# 34           7.3         350
# 1            6.9        2413
# 3            6.1          34
# 21           6.5         199
# 24           7.1         365
# 18           6.1        1128
# 15           7.8        1343
# 4            5.7         173
# 11           5.7         210
# 37           6.9         828
# 39           6.9          50
# 48           8.1        3334
# 8            5.5         174
# 45           8.1        5915
# 42           5.4         452
# 31           6.8           4
# 9            6.6        1194
# 38           6.7          13
# 27           7.4          36
# 28           7.6         308
# 16           7.2         364
# 7            5.4          45
# 0            7.7        5415
# 33           6.4          16

# %% [markdown]
# 9. Write a Pandas program to display the first 10 rows of the DataFrame.

# %%
small_dfm.head(10)
# Out:
#                      title release_date    budget    revenue  runtime  \
# 10  The American President   1995-11-17  62000000  107879496    106.0
# 14        Cutthroat Island   1995-12-22  98000000   10017322    119.0
# 46              Pocahontas   1995-06-14  55000000  346079773     81.0
# 36            It Takes Two   1995-11-17         0          0    101.0
# 30          Twelve Monkeys   1995-12-29  29500000  168840000    129.0
# 12                   Balto   1995-12-22         0   11348324     78.0
# 34        Dead Man Walking   1995-12-29  11000000   39363635    122.0
# 1                  Jumanji   1995-12-15  65000000  262797249    104.0
# 3        Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 21                 Copycat   1995-10-27         0          0    124.0
#
#     vote_average  vote_count
# 10           6.5         199
# 14           5.7         137
# 46           6.7        1509
# 36           6.1         149
# 30           7.4        2470
# 12           7.1         423
# 34           7.3         350
# 1            6.9        2413
# 3            6.1          34
# 21           6.5         199

# %% [markdown]
# 10. Write a Pandas program to sort the DataFrame based on release_date.

# %%
small_dfm.sort_values('release_date')
# Out:
#                              title release_date    budget    revenue  runtime  \
# 4      Father of the Bride Part II   1995-02-10         0   76578911    106.0
# 28       The City of Lost Children   1995-05-16  18000000    1738611    108.0
# 46                      Pocahontas   1995-06-14  55000000  346079773     81.0
# 48              The Usual Suspects   1995-07-19   6000000   23341568    106.0
# 37                        Clueless   1995-07-19  12000000          0     97.0
# 42                   Mortal Kombat   1995-08-18  18000000  122195920    101.0
# 45                           Se7en   1995-09-22  33000000  327311859    127.0
# 27                      Persuasion   1995-09-27         0          0    104.0
# 21                         Copycat   1995-10-27         0          0    124.0
# 24               Leaving Las Vegas   1995-10-27   3600000   49800000    112.0
# 0                        Toy Story   1995-10-30  30000000  373554033     81.0
# 33                      Carrington   1995-11-08         0          0    121.0
# 18  Ace Ventura: When Nature Calls   1995-11-10  30000000  212385533     90.0
# 9                        GoldenEye   1995-11-16  58000000  352194034    130.0
# 10          The American President   1995-11-17  62000000  107879496    106.0
# 36                    It Takes Two   1995-11-17         0          0    101.0
# 15                          Casino   1995-11-22  52000000  116112375    178.0
# 16           Sense and Sensibility   1995-12-13  16500000  135000000    136.0
# 1                          Jumanji   1995-12-15  65000000  262797249    104.0
# 38        Cry, the Beloved Country   1995-12-15         0     676525    106.0
# 3                Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 8                     Sudden Death   1995-12-22  35000000   64350171    106.0
# 12                           Balto   1995-12-22         0   11348324     78.0
# 14                Cutthroat Island   1995-12-22  98000000   10017322    119.0
# 7                     Tom and Huck   1995-12-22         0          0     97.0
# 11     Dracula: Dead and Loving It   1995-12-22         0          0     88.0
# 39                     Richard III   1995-12-29         0          0    104.0
# 34                Dead Man Walking   1995-12-29  11000000   39363635    122.0
# 30                  Twelve Monkeys   1995-12-29  29500000  168840000    129.0
# 31                Wings of Courage   1996-09-18         0          0     50.0
#
#     vote_average  vote_count
# 4            5.7         173
# 28           7.6         308
# 46           6.7        1509
# 48           8.1        3334
# 37           6.9         828
# 42           5.4         452
# 45           8.1        5915
# 27           7.4          36
# 21           6.5         199
# 24           7.1         365
# 0            7.7        5415
# 33           6.4          16
# 18           6.1        1128
# 9            6.6        1194
# 10           6.5         199
# 36           6.1         149
# 15           7.8        1343
# 16           7.2         364
# 1            6.9        2413
# 38           6.7          13
# 3            6.1          34
# 8            5.5         174
# 12           7.1         423
# 14           5.7         137
# 7            5.4          45
# 11           5.7         210
# 39           6.9          50
# 34           7.3         350
# 30           7.4        2470
# 31           6.8           4

# %% [markdown]
# 11. Write a Pandas program to access those movies, released after 1995-12-01

# %%
small_dfm[small_dfm['release_date']>'1995-12-01'].sort_values(by='release_date')
# Out:
#                           title release_date    budget    revenue  runtime  \
# 16        Sense and Sensibility   1995-12-13  16500000  135000000    136.0
# 1                       Jumanji   1995-12-15  65000000  262797249    104.0
# 38     Cry, the Beloved Country   1995-12-15         0     676525    106.0
# 14             Cutthroat Island   1995-12-22  98000000   10017322    119.0
# 12                        Balto   1995-12-22         0   11348324     78.0
# 3             Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 11  Dracula: Dead and Loving It   1995-12-22         0          0     88.0
# 8                  Sudden Death   1995-12-22  35000000   64350171    106.0
# 7                  Tom and Huck   1995-12-22         0          0     97.0
# 30               Twelve Monkeys   1995-12-29  29500000  168840000    129.0
# 34             Dead Man Walking   1995-12-29  11000000   39363635    122.0
# 39                  Richard III   1995-12-29         0          0    104.0
# 31             Wings of Courage   1996-09-18         0          0     50.0
#
#     vote_average  vote_count
# 16           7.2         364
# 1            6.9        2413
# 38           6.7          13
# 14           5.7         137
# 12           7.1         423
# 3            6.1          34
# 11           5.7         210
# 8            5.5         174
# 7            5.4          45
# 30           7.4        2470
# 34           7.3         350
# 39           6.9          50
# 31           6.8           4

# %% [markdown]
# 12. Write a Pandas program to sort movies on runtime in descending order.

# %%
small_dfm.sort_values('runtime',ascending=False)
# Out:
#                              title release_date    budget    revenue  runtime  \
# 15                          Casino   1995-11-22  52000000  116112375    178.0
# 16           Sense and Sensibility   1995-12-13  16500000  135000000    136.0
# 9                        GoldenEye   1995-11-16  58000000  352194034    130.0
# 30                  Twelve Monkeys   1995-12-29  29500000  168840000    129.0
# 3                Waiting to Exhale   1995-12-22  16000000   81452156    127.0
# 45                           Se7en   1995-09-22  33000000  327311859    127.0
# 21                         Copycat   1995-10-27         0          0    124.0
# 34                Dead Man Walking   1995-12-29  11000000   39363635    122.0
# 33                      Carrington   1995-11-08         0          0    121.0
# 14                Cutthroat Island   1995-12-22  98000000   10017322    119.0
# 24               Leaving Las Vegas   1995-10-27   3600000   49800000    112.0
# 28       The City of Lost Children   1995-05-16  18000000    1738611    108.0
# 38        Cry, the Beloved Country   1995-12-15         0     676525    106.0
# 8                     Sudden Death   1995-12-22  35000000   64350171    106.0
# 48              The Usual Suspects   1995-07-19   6000000   23341568    106.0
# 10          The American President   1995-11-17  62000000  107879496    106.0
# 4      Father of the Bride Part II   1995-02-10         0   76578911    106.0
# 39                     Richard III   1995-12-29         0          0    104.0
# 1                          Jumanji   1995-12-15  65000000  262797249    104.0
# 27                      Persuasion   1995-09-27         0          0    104.0
# 42                   Mortal Kombat   1995-08-18  18000000  122195920    101.0
# 36                    It Takes Two   1995-11-17         0          0    101.0
# 7                     Tom and Huck   1995-12-22         0          0     97.0
# 37                        Clueless   1995-07-19  12000000          0     97.0
# 18  Ace Ventura: When Nature Calls   1995-11-10  30000000  212385533     90.0
# 11     Dracula: Dead and Loving It   1995-12-22         0          0     88.0
# 46                      Pocahontas   1995-06-14  55000000  346079773     81.0
# 0                        Toy Story   1995-10-30  30000000  373554033     81.0
# 12                           Balto   1995-12-22         0   11348324     78.0
# 31                Wings of Courage   1996-09-18         0          0     50.0
#
#     vote_average  vote_count
# 15           7.8        1343
# 16           7.2         364
# 9            6.6        1194
# 30           7.4        2470
# 3            6.1          34
# 45           8.1        5915
# 21           6.5         199
# 34           7.3         350
# 33           6.4          16
# 14           5.7         137
# 24           7.1         365
# 28           7.6         308
# 38           6.7          13
# 8            5.5         174
# 48           8.1        3334
# 10           6.5         199
# 4            5.7         173
# 39           6.9          50
# 1            6.9        2413
# 27           7.4          36
# 42           5.4         452
# 36           6.1         149
# 7            5.4          45
# 37           6.9         828
# 18           6.1        1128
# 11           5.7         210
# 46           6.7        1509
# 0            7.7        5415
# 12           7.1         423
# 31           6.8           4

# %% [markdown]
# 13. Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million.

# %%
small_dfm[(small_dfm['revenue']> 2000000) &(small_dfm['budget']<1000000) ]
# Out:
#                           title release_date  budget   revenue  runtime  \
# 12                        Balto   1995-12-22       0  11348324     78.0
# 4   Father of the Bride Part II   1995-02-10       0  76578911    106.0
#
#     vote_average  vote_count
# 12           7.1         423
# 4            5.7         173

# %% [markdown]
# 14. Write a Pandas program to get the longest runtime and shortest runtime.

# %%
small_dfm[small_dfm['runtime']==small_dfm['runtime'].max()]
# Out:
#      title release_date    budget    revenue  runtime  vote_average  \
# 15  Casino   1995-11-22  52000000  116112375    178.0           7.8
#
#     vote_count
# 15        1343

# %%
small_dfm[small_dfm['runtime']==small_dfm['runtime'].min()]
# Out:
#                title release_date  budget  revenue  runtime  vote_average  \
# 31  Wings of Courage   1996-09-18       0        0     50.0           6.8
#
#     vote_count
# 31           4

# %% [markdown]
# 15. Write a Pandas program to calculate the number of votes garnered by the 70% movie.

# %%
small_dfm['vote_average'].quantile(0.70)
# Out:
# 7.13

# %% [markdown]
# 16. Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes.

# %%
small_dfm2= dfm[['title','runtime']].sample(30)
small_dfm2[(small_dfm2['runtime']> 30) &(small_dfm2['runtime']<360)].sort_values(by='runtime')
# Out:
#                              title  runtime
# 31                Wings of Courage     50.0
# 12                           Balto     78.0
# 0                        Toy Story     81.0
# 46                      Pocahontas     81.0
# 11     Dracula: Dead and Loving It     88.0
# 32                            Babe     89.0
# 18  Ace Ventura: When Nature Calls     90.0
# 47           When Night Is Falling     96.0
# 7                     Tom and Huck     97.0
# 37                        Clueless     97.0
# 2                 Grumpier Old Men    101.0
# 42                   Mortal Kombat    101.0
# 36                    It Takes Two    101.0
# 19                     Money Train    103.0
# 27                      Persuasion    104.0
# 1                          Jumanji    104.0
# 39                     Richard III    104.0
# 20                      Get Shorty    105.0
# 10          The American President    106.0
# 8                     Sudden Death    106.0
# 43                      To Die For    106.0
# 28       The City of Lost Children    108.0
# 23                          Powder    111.0
# 24               Leaving Las Vegas    112.0
# 44   How To Make An American Quilt    116.0
# 40                 Dead Presidents    119.0
# 21                         Copycat    124.0
# 45                           Se7en    127.0
# 9                        GoldenEye    130.0
# 13                           Nixon    192.0

# %% [markdown]
# 17. Write a Pandas program to display the movies (title, number of votes) that received specified number of votes.

# %%
small_dfm3=dfm[['title','vote_count']]
small_dfm3[small_dfm3['vote_count']> 700].sort_values(by='vote_count')
# Out:
#                              title  vote_count
# 32                            Babe         756
# 37                        Clueless         828
# 18  Ace Ventura: When Nature Calls        1128
# 9                        GoldenEye        1194
# 15                          Casino        1343
# 46                      Pocahontas        1509
# 5                             Heat        1886
# 1                          Jumanji        2413
# 30                  Twelve Monkeys        2470
# 48              The Usual Suspects        3334
# 0                        Toy Story        5415
# 45                           Se7en        5915
